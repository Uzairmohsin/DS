# %%
a = 2

# %%
b = 4

# %%
a + b
# Out:
# 6

# %%
name = "Uzair"

# %%
print(name)
# Out:
# Uzair

# %%
print("Hello world")
# Out:
# Hello world

# %%
t = "1234"
v = "5673"

# %%
print(int(t)+int(v))
# Out:
# 6907
